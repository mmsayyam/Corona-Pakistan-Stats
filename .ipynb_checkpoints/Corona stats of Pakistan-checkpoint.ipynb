# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = requests.get('http://covid.gov.pk/')

# %%
raw_file = pd.read_excel('Spreadsheets/Corona Stats of Pakistan.xlsx')
raw_file
# Out:
#            Headers OverallCounts    CityNames CityWiseCounts       Date
# 0        Recovered           572          ICT            102 2020-04-09
# 1         Critical            31       Punjab          2,171 2020-04-09
# 2           Deaths            63        Sindh          1,128 2020-04-09
# 3   Cases (24 HRS)            92           KP            560 2020-04-09
# 4  Deaths (24 HRS)             5  Balochistan            212 2020-04-09
# 5   Tests (24 HRS)         2,737          AJK             28 2020-04-09
# 6      Total Tests        44,896           GB            213 2020-04-09

# %%
df_file = raw_file.copy()
df_file
# Out:
#            Headers OverallCounts    CityNames CityWiseCounts       Date
# 0        Recovered           572          ICT            102 2020-04-09
# 1         Critical            31       Punjab          2,171 2020-04-09
# 2           Deaths            63        Sindh          1,128 2020-04-09
# 3   Cases (24 HRS)            92           KP            560 2020-04-09
# 4  Deaths (24 HRS)             5  Balochistan            212 2020-04-09
# 5   Tests (24 HRS)         2,737          AJK             28 2020-04-09
# 6      Total Tests        44,896           GB            213 2020-04-09

# %%
soup = BeautifulSoup(url.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="covid, corona, corona pakistan, covid19, pakistan corona, corona diesease, wuhan virus, corona virus, pakistan corona deaths, pakistan corona infections, pakistan corona case, official corona pakistan website" name="Keywords">
# <!-- CSRF Token -->
# <meta content="tWPDXY4lmmmMvD7WdPtVFelyC88ykgyVCyVBkhiB" name="csrf-token"/>
# <title> COVID-19 Health Advisory Platform by Ministry of National Health Services Regulations and Coordination </title>
# <link href="http://covid.gov.pk/theme_img/core-img/fevo.ico" rel="icon" sizes="16x16" type="image/ico"/>
# <!-- Styles -->
# <link href="http://covid.gov.pk/theme_css/style.css" rel="stylesheet"/>
# <!-- Styles -->
# <link href="http://covid.gov.pk/theme_css/style-ad.css" rel="stylesheet"/>
# <!-- Styles -->
# <link href="http://covid.gov.pk/theme_css/style-ksh.css" rel="stylesheet"/>
# <link href="https://cdn.datatables.net/1.10.16/css/jquery.dataTables.min.css" rel="stylesheet"/>
# <link href="https://cdn.datatables.net/1.10.19/css/dataTables.bootstrap4.min.css" rel="stylesheet"/>
# </meta></head>
# <body class="light-version">
# <div id="preloader">
# <div class="preload-content">
# <div id="dream-load"></div>
# </div>
# </div>
# <div id="app">
# <header class="header-area fadeInDown sticky" data-wow-delay="0.2s">
# <div class="co-top-bar">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-12">
# <p>Dial <strong>1166</strong> health helpline</p>
# </div>
# </div>
# </div>
# </div>
# <div class="classy-nav-container light breakpoint-off">
# <div class="container">
# <!-- Classy Menu -->
# <nav class="classy-navbar light justify-content-between" id="dreamNav">
# <!-- Logo -->
# <a class="nav-brand light" href="http://covid.gov.pk"><img alt="logo" src="http://covid.gov.pk/theme_img/core-img/logo.png"/></a>
# <!-- Navbar Toggler -->
# <div class="classy-navbar-toggler demo">
# <span class="navbarToggler"><span></span><span></span><span></span></span>
# </div>
# <!-- Menu -->
# <div class="classy-menu">
# <!-- close btn -->
# <div class="classycloseIcon">
# <div class="cross-wrap"><span class="top"></span><span class="bottom"></span></div>
# </div>
# <!-- Nav Start -->
# <div class="classynav">
# <ul id="nav">
# <li>
# <a href="http://covid.gov.pk/stats/pakistan" style="color: red !important; font-size: 16px !important; font-weight: bold;">Stats</a>
# <ul class="dropdown">
# <li><a href="http://covid.gov.pk/stats/pakistan">Pakistan</a></li>
# <li><a href="http://covid.gov.pk/stats/ict">ICT</a></li>
# <li><a href="http://covid.gov.pk/stats/punjab">Punjab</a></li>
# <li><a href="http://covid.gov.pk/stats/sindh">Sindh</a></li>
# <li><a href="http://covid.gov.pk/stats/kpk">KPK</a></li>
# <li><a href="http://covid.gov.pk/stats/balochistan">Balochistan</a></li>
# <li><a href="http://covid.gov.pk/stats/gilgit-baltistan">Gilgit Baltistan</a></li>
# <li><a href="http://covid.gov.pk/stats/ajk">AJK</a></li>
# <li><a href="http://covid.gov.pk/stats/global">International Cases</a></li>
# </ul>
# </li>
# </ul></div></div></nav></div></div></header></div></body></html>
# <li><a href="http://covid.gov.pk/covid19">covid-19</a></li>
# <li><a href="http://covid.gov.pk/chatbot">Chat Bot</a></li>
# <li><a href="http://covid.gov.pk/guideline">Guidelines</a></li>
# <li><a href="http://covid.gov.pk/prevention">Prevention</a></li>
# <li>
# <a href="http://covid.gov.pk">Facilities</a>
# <ul class="dropdown facil-drp-dwn">
# <li><a href="http://covid.gov.pk/facilities/List of COVID-19 Designated Tertiary Care Hospitals Pakistan.pdf">Designated Tertiary Care Hospitals</a></li>
# <li><a href="http://covid.gov.pk/facilities/List of Province-wise COVID-19 Hospital Isolation Wards Pakistan.pdf">Hospital Isolation Wards</a></li>
# <li><a href="http://covid.gov.pk/facilities/List of Province-wise COVID-19 Quarantine Facilities Pakistan.pdf">Quarantine Facilities</a></li>
# <li><a href="http://covid.gov.pk/facilities/Labs-new.pdf">Testing Facilities Pakistan</a></li>
# <li><a href="http://covid.gov.pk/facilities/List-of-Designated-Hospitals-1.pdf">Designated Hospitals</a></li>
# </ul>
# </li>
# <li><a href="http://covid.gov.pk/faq">FAQ</a></li>
# <li><a href="http://covid.gov.pk/public_service_message">Public Service Message</a></li>
#
# <!-- Button -->
# <!--   <a href="#" class="btn login-btn ml-50">Log in</a> -->
#
# <!-- Nav End -->
#
#
#
#
#
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-160831327-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-160831327-1');
# </script>
# <script language="JavaScript" type="text/javascript">
# setTimeout("location.href = '/'",3600000); // milliseconds, so 10 seconds = 10000ms
# </script>
# <!-- ##### Welcome Area Start ##### -->
# <section class="hero-section ico-bg4 relative section-padding" id="home">
# <div class="hero-section-content">
# <div class="container h-100">
# <div class="row h-100 mb-50 align-items-center">
# <!-- Welcome Content -->
# <div class="col-12 col-lg-8 col-md-12">
# <div class="welcome-content">
# <div class="promo-section">
# <h3 class="special-head gradient-text cyan">KNOW ABOUT COVID-19</h3>
# </div>
# <h1 class="w-text wow fadeInUp" data-wow-delay="0.2s">See the Realtime Pakistan and Worldwide COVID-19 situation!</h1>
# <!--   <p class="g-text wow fadeInUp" data-wow-delay="0.3s">Be Aware, But Donâ€™t Panic: How To Deal With Coronavirus Fears</p> -->
# <p class="g-text wow fadeInUp" data-wow-delay="0.5s">
#               The coronavirus, or COVID-19, is inciting panic for a number of reasons. It&amp;aposs a new virus, meaning no one has immunity, and there is no vaccine. Its novelty means that scientists aren&amp;apost sure yet how it behaves they have little history to go on.
#             </p>
# <!--  <div class="dream-btn-group wow fadeInUp" data-wow-delay="0.4s">
#               <a href="http://covid.gov.pk/covid19" class="btn more-btn"> Learn more</a>
#             </div> -->
# </div>
# </div>
# <div class="dream-btn-group wow fadeInUp main-bannr-btn" style="visibility: visible;">
# <a class="btn more-btn" href="http://covid.gov.pk/stats/pakistan">Pakistan Cases details</a>
# <a class="btn more-btn" href="http://covid.gov.pk/stats/global">International Cases details</a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ##### Welcome Area End ##### -->
# <div class="clearfix"></div>
# <div class="container">
# <div class="mt-5" id="statistics">
# <div class="row">
# <div class="col-12 col-md-6 wow fadeInUp" data-wow-delay="0.2s" style="visibility: visible; animation-delay: 0.2s; animation-name: fadeInUp;">
# <span class="score-img"><img src="http://covid.gov.pk/theme_img/core-img/Corona-Logo2.gif"/></span>
# <h5>Coronavirus in Pakistan</h5>
# <h2>Confirmed<br/>Cases</h2>
# <h1 class="text-muted numbers-main">4,601</h1>
# </div>
# <div class="col-12 col-md-6 text-center numbers-child wow fadeInUp" data-wow-delay="0.4s" style="visibility: visible; animation-delay: 0.4s; animation-name: fadeInUp;">
# <div class="row">
# <div class="col-12 col-md-4">
# <h6 style="color: rgb(67, 160, 71);">Recovered</h6>
# <h4 class="text-muted" style="color: rgb(67, 160, 71);">727</h4>
# </div>
# <div class="col-12 col-md-4">
# <h6 style="color: rgb(30, 136, 229);">Critical</h6>
# <h4 class="text-muted" style="color: rgb(30, 136, 229);">45</h4>
# </div>
# <div class="col-12 col-md-4">
# <h6 style="color: rgb(255, 0, 0);">Deaths</h6>
# <h4 class="text-muted" style="color: rgb(255, 0, 0);">66</h4>
# </div>
# <div class="col-6 col-lg-3 col-md-6">
# <h6 style="color: rgb(30, 136, 229);">Cases (24 HRS)</h6>
# <h4 class="text-muted" style="color: rgb(30, 136, 229);">284</h4>
# </div>
# <div class="col-6 col-lg-3 col-md-6">
# <h6 style="color: rgb(30, 136, 229);">Deaths (24 HRS)</h6>
# <!--  <span class="time-to-time-home">12pm to 12pm</span> -->
# <h4 class="text-muted" style="color: rgb(30, 136, 229);">4</h4>
# </div>
# <div class="col-6 col-lg-3 col-md-6">
# <h6 style="color: rgb(30, 136, 229);">Tests (24 HRS)</h6>
# <h4 class="text-muted" style="color: rgb(30, 136, 229);">2,478</h4>
# </div>
# <div class="col-6 col-lg-3 col-md-6">
# <h6 style="color: rgb(30, 136, 229);">Total Tests</h6>
# <h4 class="text-muted" style="color: rgb(30, 136, 229);">54,706</h4>
# </div>
# </div>
# </div>
# </div>
# <div class="row provinc-stat">
# <div class="col">
# <h6><a href="stats/ict">ICT</a></h6>
# <h4 class="text-muted">107</h4>
# </div>
# <div class="col">
# <h6><a href="stats/punjab">Punjab</a></h6>
# <h4 class="text-muted">2,279</h4>
# </div>
# <div class="col">
# <h6><a href="stats/sindh">Sindh</a></h6>
# <h4 class="text-muted">1,128</h4>
# </div>
# <div class="col">
# <h6><a href="stats/kpk">KP</a></h6>
# <h4 class="text-muted">620</h4>
# </div>
# <div class="col">
# <h6><a href="stats/balochistan">Balochistan</a></h6>
# <h4 class="text-muted">219</h4>
# </div>
# <div class="col">
# <h6><a href="stats/ajk">AJK</a></h6>
# <h4 class="text-muted">33</h4>
# </div>
# <div class="col">
# <h6><a href="stats/gilgit-baltistan">GB</a></h6>
# <h4 class="text-muted">215</h4>
# </div>
# </div>
# <div class="text-right" id="date">
#     LAST UPDATED AT: 10 Apr, 2020 - 09:17am
#    </div>
# <div style="font-size: 12px; color: red; margin-bottom: 8px; margin-top: 2px; text-align: right;">*Dashboard numbers are updated as soon as authenticated test results are received from the laboratories.</div>
# <div class="dream-btn-group wow fadeInUp" style="visibility: visible;">
# <a class="btn more-btn" href="http://covid.gov.pk/stats/pakistan">Pakistan Cases details</a>
# <a class="btn more-btn" href="http://covid.gov.pk/stats/global">International Cases details</a>
# </div>
# </div>
# </div>
# <section class="what-we-do relative sec-before3 section-padding-100" id="features">
# <div class="container">
# <div class="section-heading text-center">
# <h2 class="fadeInUp" data-wow-delay="0.3s">Corona Virus <span class="gradient-text blue normal">Symptoms</span></h2>
# <p class="fadeInUp" data-wow-delay="0.4s">It can take up to 14 days for symptoms of coronavirus to appear. The main symptoms to look out for are:</p>
# </div>
# <div class="clearfix"></div>
# <div class="outer">
# <!--Logo-->
# <div class="inner-circle"><a href="#"><img alt="image" class="phone" src="http://covid.gov.pk/theme_img/core-img/about2.png"/></a></div>
# <div class="row clearfix">
# <!--Left Column-->
# <div class="left-column col-lg-4 col-md-6 col-sm-6 col-xs-12">
# <!--Service Box-->
# <div class="service-box-three">
# <div class="inner-box">
# <div class="icon-box"><img alt="" src="http://covid.gov.pk/theme_img/icons/w1.png"/></div>
# <h3><a>Coughing </a></h3>
# </div>
# </div>
# <!--Service Box-->
# <div class="service-box-three">
# <div class="inner-box">
# <div class="icon-box"><img alt="" src="http://covid.gov.pk/theme_img/icons/w3.png"/></div>
# <h3><a>Shortness of Breath</a></h3>
# </div>
# </div>
# </div>
# <!--Right Column-->
# <div class="right-column col-lg-4 col-md-6 col-sm-6 col-xs-12">
# <!--Service Box-->
# <div class="service-box-four">
# <div class="inner-box">
# <div class="icon-box"><img alt="" src="http://covid.gov.pk/theme_img/icons/w4.png"/></div>
# <h3><a>Hot Fever</a></h3>
# </div>
# </div>
# <!--Service Box-->
# <div class="service-box-four">
# <div class="inner-box">
# <div class="icon-box"><img alt="" src="http://covid.gov.pk/theme_img/icons/w5.png"/></div>
# <h3><a>Sore Throat</a></h3>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ##### About Us Area Start ##### -->
# <section class="about-us-area section-padding-0-70 clearfix">
# <div class="container">
# <div>
# <div class="row align-items-center">
# <div class="col-12 col-lg-6 offset-lg-0 col-md-12 no-padding-left">
# <img alt="" class="img-responsive" src="http://covid.gov.pk/theme_img/core-img/about-new-01.png"/>
# </div>
# <div class="col-12 col-lg-6 offset-lg-0">
# <div class="who-we-contant">
# <div class="dream-dots text-left fadeInUp" data-wow-delay="0.2s">
# <span class="gradient-text blue">Precautions</span>
# </div>
# <h4 class="fadeInUp" data-wow-delay="0.3s">Ways to prevent the disease</h4>
# <!-- <p class="fadeInUp" data-wow-delay="0.4s">Lorem ipsum dolor sit amet, consectetur adipisicing elit. Suscipit eum illum tempora? Ducimus eum culpa voluptates dolorem dolorum et sit nisi, mollitia animi porro fuga sequi, molestias repellat excepturi nobis eum culpa voluptates dolorem dolorum et.</p> -->
# <div class="services-block-four v2 mt-30">
# <div class="inner-box">
# <div class="icon-font-box">
# <i class="fa fa-check"></i>
# </div>
# <h3><a href="#">Wash Your Hands For 20sec</a></h3>
# <div class="text width-80">Wash hands often with soap and water for at least 20 seconds.</div>
# </div>
# </div>
# <div class="services-block-four v2">
# <div class="inner-box">
# <div class="icon-font-box">
# <i class="fa fa-check"></i>
# </div>
# <h3><a href="#">Cover Nose &amp; Mouth When Sneezing</a></h3>
# <div class="text width-80">Cover coughs and sneezes with tissues.</div>
# </div>
# </div>
# <div class="services-block-four v2">
# <div class="inner-box">
# <div class="icon-font-box">
# <i class="fa fa-check"></i>
# </div>
# <h3><a href="#">Use Sanitizer</a></h3>
# <div class="text width-80">Use hand sanitizer if soap and water are not available.</div>
# </div>
# </div>
# <div class="services-block-four v2">
# <div class="inner-box">
# <div class="icon-font-box">
# <i class="fa fa-check"></i>
# </div>
# <h3><a href="#">Avoid Crowded Places (Social Distancing)</a></h3>
# <div class="text width-80">As an individual, you can lower your risk of infection by reducing your rate of contact with other people. Avoiding public spaces and unnecessary social gatherings, especially events with large numbers of people or crowds, will lower the chance that you will be exposed to the coronavirus as well as to other infectious diseases like flu.</div>
# </div>
# </div>
# <div class="services-block-four v2">
# <div class="inner-box">
# <div class="icon-font-box">
# <i class="fa fa-check"></i>
# </div>
# <h3><a href="#">Avoid Contact with Sick People</a></h3>
# <div class="text width-80">Avoid close contact with anyone showing symptoms of respiratory illness.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-padding-70-0">
# <div class="section-heading text-center">
# <!-- Dream Dots -->
# <div class="dream-dots justify-content-center fadeInUp" data-wow-delay="0.2s">
# <span class="gradient-text blue">We should be aware</span>
# </div>
# <h2 class="fadeInUp" data-wow-delay="0.3s">Myths about COVID-19</h2>
# </div>
# <div class="row">
# <div class="col-12 col-lg-6 offset-lg-0 col-md-12 no-padding-left">
# <div class="owl-slider" id="about">
# <div class="owl-carousel" id="carousel">
# <div class="item">
# <div class="responsibilities-item animate fadeInUp animated" data-animation="fadeInUp" data-duration="200">
# <i><img src="http://covid.gov.pk/theme_img/svg/mosquito.svg"/></i>
# <h5>
#                     The new coronavirus CANNOT be transmitted through mosquito bites.
#                   </h5>
# <p><span style="color: #3c4245;">The new coronavirus is a respiratory virus which spreads primarily through droplets generated when an infected person coughs or sneezes, or through droplets of saliva or discharge from the nose. To date there has been no information nor evidence to suggest that the new coronavirus could be transmitted by mosquitoes.</span></p>
# </div>
# </div>
# <div class="item">
# <div class="responsibilities-item animate fadeInUp animated" data-animation="fadeInUp" data-duration="200">
# <i><img src="http://covid.gov.pk/theme_img/svg/cold.svg"/></i>
# <h5>
#                   Cold weather and snow CANNOT kill the new coronavirus.
#                 </h5>
# <p><span style="color: #3c4245;">There is no reason to believe that cold weather can kill the new coronavirus or other diseases. The normal human body temperature remains around 36.5Â°C to 37Â°C, regardless of the external temperature or weather. </span></p>
# </div>
# </div>
# <div class="item">
# <div class="responsibilities-item animate fadeInUp animated" data-animation="fadeInUp" data-duration="200">
# <i><img src="http://covid.gov.pk/theme_img/svg/antibiotics.svg"/></i>
# <h5>
#                 Antibiotics do not work against viruses, only bacteria
#               </h5>
# <p><span style="color: #3c4245;">The new coronavirus (2019-nCoV) is a virus and, therefore, antibiotics should not be used as a means of prevention or treatment.</span></p>
# <p><span style="color: #3c4245;">However, if you are hospitalized for the 2019-nCoV, you may receive antibiotics because bacterial co-infection is possible.</span></p>
# </div>
# </div>
# <div class="item">
# <div class="responsibilities-item animate fadeInUp animated" data-animation="fadeInUp" data-duration="200">
# <i><img src="http://covid.gov.pk/theme_img/svg/newcoronavirus.svg"/></i>
# <h5>
#               The new coronavirus cannot be transmitted through goods manufactured in China or any country reporting COVID-19 cases.
#             </h5>
# <p><span>Yes it is safe. People receiving imported goods or packages from China are not exposed to the risk of getting the new coronavirus. We know from experience that it is very unlikely that the virus would survive for a long time on things such as letters or packages.<br/></span></p>
# </div>
# </div>
# <div class="item">
# <div class="responsibilities-item animate fadeInUp animated" data-animation="fadeInUp" data-duration="200">
# <i><img src="http://covid.gov.pk/theme_img/svg/garlic.svg"/></i>
# <h5>
#             There is no evidence from the current outbreak that eating garlic has protected people from the new coronavirus
#           </h5>
# <p><span style="color: #3c4245;">Garlic is a healthy food that may have some antimicrobial properties. However, there is no evidence from the current outbreak that eating garlic has protected people from the new coronavirus.</span></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-6 mt-s">
# <div class="service-img-wrapper mb-30">
# <div class="image-box">
# <img alt="" class="center-block img-responsive phone-img" src="http://covid.gov.pk/theme_img/core-img/corona2020.png"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ##### About Us Area End ##### -->
# <div class="faq-timeline-area transparent section-padding-0-85" id="faq">
# <div class="container">
# <div class="section-heading text-center">
# <!-- Dream Dots -->
# <div class="dream-dots justify-content-center fadeInUp" data-wow-delay="0.2s">
# <span class="gradient-text blue">WE ARE HERE TO HELP YOU</span>
# </div>
# <h2 class="fadeInUp" data-wow-delay="0.3s"> Frequently Asked Questions!</h2>
# </div>
# <div class="row align-items-center">
# <div class="col-12 col-lg-6">
# <img alt="" class="img-responsive" src="http://covid.gov.pk/theme_img/core-img/corona-pakistan.png"/>
# </div>
# <div class="col-12 col-lg-6 col-md-12">
# <div class="dream-faq-area mt-s">
# <dl style="margin-bottom:0">
# <!-- Single FAQ Area -->
# <dt class="wave fadeInUp v2" data-wow-delay="0.2s">What is Isolation?</dt>
# <dd class="fadeInUp" data-wow-delay="0.3s">
# <p>Separation of the affected person or suspected of being infected from other healthy people for the duration of the disease infection in appropriate places and health conditions, in order to prevent the transmission of the infection.</p>
# </dd>
# <!-- Single FAQ Area -->
# <dt class="wave fadeInUp v2" data-wow-delay="0.3s">What is the difference between isolation and quarantine?</dt>
# <dd>
# <p>Isolation and quarantine are common public health strategies used to help prevent the spread of infectious diseases. Isolation and quarantine keep people who are sick or exposed to illness isolated for a deï¬ned period of time to prevent the disease spread</p>
# </dd>
# <!-- Single FAQ Area -->
# <dt class="wave fadeInUp v2" data-wow-delay="0.4s">Why this Prevention important for me?</dt>
# <dd>
# <p>
#                 You may be asked to:<br/>
# <ul>
# <li>Stay at home</li>
# <li>Stay away from others</li>
# <li>Ensure that there are no symptoms of the disease</li>
# <li>Contact the doctor if you develop symptoms</li>
# </ul>
# </p>
# </dd>
# <!-- Single FAQ Area -->
# <dt class="wave fadeInUp v2" data-wow-delay="0.5s">Does Isolation and quarantine prevent infection of others?</dt>
# <dd>
# <p>Quarantine and isolation are effective measures that are taken to reduce the spread of the disease to all members of society</p>
# </dd>
# <dt class="wave fadeInUp v2" data-wow-delay="0.5s">What is Quarantine?</dt>
# <dd>
# <p>Restricting the activities of healthy people for a period of time as determined by the competent medical authorities</p>
# </dd>
# </dl>
# </div>
# <div class="dream-btn-group wow fadeInUp" data-wow-delay="0.7s" style="visibility: visible; animation-delay: 0.7s; animation-name: fadeInUp;">
# <a class="btn more-btn" href="http://covid.gov.pk/faq">Read More</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- ##### Team Area Start ##### -->
# <section class="our_team_area section-padding-0-70 clearfix" id="team">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <div class="section-heading text-center">
# <!-- Dream Dots -->
# <div class="dream-dots justify-content-center fadeInUp" data-wow-delay="0.2s">
# <span class="gradient-text blue">Ministry of National Health Services Regulations &amp; Coordinations</span>
# </div>
# <h2 class="fadeInUp" data-wow-delay="0.3s">Leadership</h2>
# </div>
# </div>
# </div>
# <div class="row">
# <!-- Single Team Member -->
# <div class="col-12 col-sm-6 col-lg-4 col-md-4">
# <div class="our-team ico-team">
# <div class="team_img">
# <img alt="chef-1" class="mt-30 width-80" src="http://covid.gov.pk/theme_img/team-img/1.jpg"/>
# <ul class="social">
# <li><a href="https://www.facebook.com/ImranKhanOfficial"><i class="fa fa-facebook"></i></a></li>
# <li><a href="https://twitter.com/ImranKhanPTI"><i class="fa fa-twitter"></i></a></li>
# </ul>
# </div>
# <div class="team-content">
# <h4 class="title">Imran Khan</h4>
# <span class="post">PRIME MINISTER OF PAKISTAN</span>
# </div>
# </div>
# </div>
# <!-- Single Team Member -->
# <div class="col-12 col-sm-6 col-lg-4 col-md-4">
# <div class="our-team ico-team">
# <div class="team_img">
# <img alt="chef-1" class="mt-30 width-80" src="http://covid.gov.pk/theme_img/team-img/3.jpg"/>
# <ul class="social">
# <li><a href="https://twitter.com/zfrmrza?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor"><i class="fa fa-twitter"></i></a></li>
# </ul>
# </div>
# <div class="team-content">
# <h4 class="title">Dr. Zafar Mirza</h4>
# <span class="post">SPECIAL ASSISTANT TO PRIME MINISTER ON HEALTH</span>
# </div>
# </div>
# </div>
# <!-- Single Team Member -->
# <div class="col-12 col-sm-6 col-lg-4 col-md-4">
# <div class="our-team ico-team">
# <div class="team_img">
# <img alt="chef-1" class="mt-30 width-80" src="http://covid.gov.pk/theme_img/team-img/4.jpg"/>
# <!--      <ul class="social">
#                                     <li><a href="#"><i class="fa fa-facebook"></i></a></li>
#                                     <li><a href="#"><i class="fa fa-twitter"></i></a></li>
#                                     <li><a href="#"><i class="fa fa-linkedin"></i></a></li>
#                                   </ul> -->
# </div>
# <div class="team-content">
# <h4 class="title">Dr Tanveer Ahmad Qureshi</h4>
# <span class="post">SECRETARY</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="container">
# <a class="twitter-timeline" data-height="450px" data-width="100%" href="https://twitter.com/zfrmrza?ref_src=twsrc%5Etfw">Tweets by zfrmrza</a> <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js"></script>
# <div>
# <!-- ##### Team Area End ##### -->
# <section class="our_blog_area clearfix section-padding-100-0" id="blog">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <div class="section-heading text-center">
# <!-- Dream Dots -->
# <div class="dream-dots justify-content-center fadeInUp" data-wow-delay="0.2s">
# <span class="gradient-text blue">News</span>
# </div>
# <h2 class="fadeInUp" data-wow-delay="0.3s">Latest information</h2>
# <p class="fadeInUp" data-wow-delay="0.4s">The information may be changed or updated to ensure that it's the latest and up-to-date to meet the website viewers needs and requirements.</p>
# </div>
# </div>
# </div>
# <div class="row justify-content-center">
# <!-- Single Blog Post -->
# <div class="col-12 col-md-4 col-lg-4">
# <div class="single-blog-area fadeInUp" data-wow-delay="0.2s">
# <!-- Post Thumbnail -->
# <div class="blog_thumbnail">
# <img alt="" src="http://covid.gov.pk/uploads/news/22March2020_thumb2.jpg"/>
# </div>
# <!-- Post Content -->
# <div class="blog-content">
# <!-- Dream Dots -->
# <div class="post-meta mt-20">
# <p> <a href="https://www.facebook.com/1455233781383220/posts/2554697634770157/?vh=e" target="_blank">2020-03-22 06:57:29</a></p>
# </div>
# <a class="post-title" href="https://www.facebook.com/1455233781383220/posts/2554697634770157/?vh=e" target="_blank">
# <h4>Cronavirus PSM 14</h4>
# </a>
# <a class="more-info" href="https://www.facebook.com/1455233781383220/posts/2554697634770157/?vh=e" target="_blank">Watch Video<i class="fa fa-long-arrow-right"></i></a>
# </div>
# </div>
# </div>
# <!-- Single Blog Post -->
# <div class="col-12 col-md-4 col-lg-4">
# <div class="single-blog-area fadeInUp" data-wow-delay="0.2s">
# <!-- Post Thumbnail -->
# <div class="blog_thumbnail">
# <img alt="" src="http://covid.gov.pk/uploads/news/22March2020_hqdefault.jpg"/>
# </div>
# <!-- Post Content -->
# <div class="blog-content">
# <!-- Dream Dots -->
# <div class="post-meta mt-20">
# <p> <a href="http://covid.gov.pk/public_service_message/22" target="_self">2020-03-22 04:24:55</a></p>
# </div>
# <a class="post-title" href="http://covid.gov.pk/public_service_message/22" target="_self">
# <h4>Cronavirus PSM 13</h4>
# </a>
# <a class="more-info" href="http://covid.gov.pk/public_service_message/22" target="_self">Watch Video<i class="fa fa-long-arrow-right"></i></a>
# </div>
# </div>
# </div>
# <!-- Single Blog Post -->
# <div class="col-12 col-md-4 col-lg-4">
# <div class="single-blog-area fadeInUp" data-wow-delay="0.2s">
# <!-- Post Thumbnail -->
# <div class="blog_thumbnail">
# <img alt="" src="http://covid.gov.pk/uploads/news/22March2020_hqdefault.jpg"/>
# </div>
# <!-- Post Content -->
# <div class="blog-content">
# <!-- Dream Dots -->
# <div class="post-meta mt-20">
# <p> <a href="http://covid.gov.pk/public_service_message/21" target="_self">2020-03-22 04:24:29</a></p>
# </div>
# <a class="post-title" href="http://covid.gov.pk/public_service_message/21" target="_self">
# <h4>Cronavirus PSM 12</h4>
# </a>
# <a class="more-info" href="http://covid.gov.pk/public_service_message/21" target="_self">Watch Video<i class="fa fa-long-arrow-right"></i></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- ##### team Area End ##### -->
# <!-- ##### Footer Area Start ##### -->
# <footer>
# <div class="footer-content-area mt-0">
# <div class="container">
# <div class="row">
# <div class="col-12 col-lg-4 col-md-6">
# <div class="footer-copywrite-info">
# <!-- Copywrite -->
# <div class="copywrite_text fadeInUp" data-wow-delay="0.2s">
# <div class="footer-logo">
# <a href="http://covid.gov.pk"><img alt="logo" src="http://covid.gov.pk/theme_img/core-img/logo.png"/></a>
# </div>
# <p>See the Realtime Pakistan and Worldwide COVID-19 situation!</p>
# </div>
# <!-- Social Icon -->
# <div class="footer-social-info fadeInUp" data-wow-delay="0.4s">
# <a href="https://www.facebook.com/NHSRCOfficial"><i aria-hidden="true" class="fa fa-facebook"></i></a>
# <a href="https://twitter.com/nhsrcofficial"> <i aria-hidden="true" class="fa fa-twitter"></i></a>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-3 col-md-6">
# <div class="contact_info_area d-sm-flex justify-content-between">
# <!-- Content Info
#               <div class="contact_info mt-x text-center fadeInUp" data-wow-delay="0.3s">
#                 <h5>PRIVACY & TOS</h5>
#                 <a href="http://covid.gov.pk"><p>Home</p></a>
#                 <a href="http://covid.gov.pk/covid19"><p>covid19</p></a>
#                 <a href="http://covid.gov.pk/prevention"><p>Prevention</p></a>
#                 <a href="http://covid.gov.pk/faq"><p>FAQ</p></a>
#                 <a href="http://covid.gov.pk/news"><p>news</p></a>
#                 <a href="#"><p>Contact</p></a>
#               </div>
#               -->
# </div>
# </div>
# <div class="col-12 col-lg-2 col-md-6">
# <!-- Content Info -->
# <div class="contact_info_area d-sm-flex justify-content-between">
# <div class="contact_info mt-s text-center fadeInUp" data-wow-delay="0.2s">
# <h5>NAVIGATE</h5>
# <a href="http://covid.gov.pk"><p>Home</p></a>
# <a href="http://covid.gov.pk/covid19"><p>COVID-19</p></a>
# <a href="http://covid.gov.pk/chatbot"><p>Chat Bot</p></a>
# <a href="http://covid.gov.pk/guideline"><p>Guidelines</p></a>
# <a href="http://covid.gov.pk/prevention"><p>Prevention</p></a>
# <a href="http://covid.gov.pk/laboratories"><p>Laboratories</p></a>
# <a href="http://covid.gov.pk/faq"><p>FAQ</p></a>
# <a href="http://covid.gov.pk/public_service_message"><p>Public Service Message</p></a>
# <a href="http://covid.gov.pk/contact"><p>Contact</p></a>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-3 col-md-6">
# <div class="contact_info_area d-sm-flex justify-content-between">
# <!-- Content Info -->
# <div class="contact_info mt-s text-center fadeInUp" data-wow-delay="0.4s">
# <h5>CONTACT US</h5>
# <p>Ministry of National Health Services Regulations &amp; Coordination,</p><p> 3rd Floor Kohsar Block,</p> <p>Islamabad</p>
# <p>+92-51-9245746</p>
# <p><a href="mailto:contact@nhsrc.gov.pk">contact@nhsrc.gov.pk</a></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-12 col-md-12 co-right-bottom">Developed by <a href="https://nitb.gov.pk/" target="_blank"> National Information Technology Board</a> in collaboration with <a href="http://www.ecompk.com" target="_blank"> ECOM PK (Pvt.) Ltd </a></div>
# </div>
# </footer> </div>
# <!-- Scripts -->
# <script src="http://covid.gov.pk/theme_js/jquery.min.js"></script>
# <script src="http://covid.gov.pk/theme_js/popper.min.js"></script>
# <script src="http://covid.gov.pk/theme_js/bootstrap.min.js"></script>
# <script src="http://covid.gov.pk/theme_js/plugins.js"></script>
# <script src="http://covid.gov.pk/theme_js/animated.js"></script>
# <script src="http://covid.gov.pk/theme_js/jquery.syotimer.min.js"></script>
# <script src="http://covid.gov.pk/theme_js/script.js"></script>
# <script src="https://cdn.datatables.net/1.10.16/js/jquery.dataTables.min.js"></script>
# <script src="https://cdn.datatables.net/1.10.19/js/dataTables.bootstrap4.min.js"></script>
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAWF3Lm7Wyi_fF4JzOgyIlaXr-VsiV61BY&amp;libraries=places"></script>
# <script src="//d.bablic.com/snippet/5e79a6f3279d870001199993.js?version=3.9"></script>
# <script src="http://covid.gov.pk/js/maps.js"></script>
# <script type="text/javascript">
#                         $("#carousel").owlCarousel({
#                           autoplay: true,
#                           lazyLoad: true,
#                           loop: true,
#                           margin: 20,
#
#                           responsiveClass: true,
#                           autoHeight: true,
#                           autoplayTimeout: 7000,
#                           smartSpeed: 800,
#                           nav: true,
#                           responsive: {
#                             0: {
#                               items: 1
#                             },
#
#                             600: {
#                               items: 1
#                             },
#
#                             1024: {
#                               items: 1
#                             },
#
#                             1366: {
#                               items: 1
#                             }
#                           }
#                         });
# 						setTimeout(function() {
#                           location.reload();
#                         }, 1800000);
#                       </script>
# <script>
#          function hideBablic(){
#              if($("iframe#bablicFlagsWidget").contents().find("a.logo").length === 1){
#                  $("iframe#bablicFlagsWidget").contents().find("a.logo").remove();
#              }
#          }
#
#          setInterval(function(){ hideBablic() }, 500);
#     </script>
# </div>

# %%
lst = []
for g in soup.findAll('div', class_ = 'col-12 col-md-6 wow fadeInUp'):
    header_name = g.find('h2')
    header_count = g.find('h1')
#     print (header_count)
    details_pak = {
        "Name" : header_name.text,
        "Count" : header_count.text 
    }
    lst.append(details_pak)
    
print (lst)
# Out:
# [{'Name': 'ConfirmedCases', 'Count': '4,601'}]

# %%
df_total_count = pd.DataFrame(lst)
df_total_count
# Out:
#    Count            Name
# 0  4,601  ConfirmedCases

# %%
lst_column_details = []
lst_count_details = []

# %%
def get_details(a, b, c):
#     a = []
    for g in soup.findAll('div', class_ = 'col-12 col-md-6 text-center numbers-child wow fadeInUp'):
        details = {}
        for i in g.findAll(a):
            details[b] = i.text
            c.append(details[b])
    return (c)

# %%
get_details('h6', 'Columns', lst_column_details)
# Out:
# ['Recovered',
#  'Critical',
#  'Deaths',
#  'Cases (24 HRS)',
#  'Deaths (24 HRS)',
#  'Tests (24 HRS)',
#  'Total Tests']

# %%
get_details('h4', 'Counts', lst_count_details)
# Out:
# ['727', '45', '66', '284', '4', '2,478', '54,706']

# %%
lst_cities = []
lst_cases = []
def get_citywise_details():
    for g in soup.findAll('div', class_='row provinc-stat'):
        names = g.findAll('a')
        for n in names:
            city_names = n.text
            dict_city = {
                "City": city_names
            }
            print (city_names)
            print (dict_city)
            lst_cities.append(dict_city)
        counts = g.findAll('h4')
        for c in counts:
            case_counts = c.text
            dict_cases = {
                "Counts": case_counts
            }
            print (case_counts)
            lst_cases.append(dict_cases)

# %%
get_citywise_details()
# Out:
# ICT
# {'City': 'ICT'}
# Punjab
# {'City': 'Punjab'}
# Sindh
# {'City': 'Sindh'}
# KP
# {'City': 'KP'}
# Balochistan
# {'City': 'Balochistan'}
# AJK
# {'City': 'AJK'}
# GB
# {'City': 'GB'}
# 107
# 2,279
# 1,128
# 620
# 219
# 33
# 215

# %%
print (lst_cities)
print (lst_cases)
# Out:
# [{'City': 'ICT'}, {'City': 'Punjab'}, {'City': 'Sindh'}, {'City': 'KP'}, {'City': 'Balochistan'}, {'City': 'AJK'}, {'City': 'GB'}]
# [{'Counts': '107'}, {'Counts': '2,279'}, {'Counts': '1,128'}, {'Counts': '620'}, {'Counts': '219'}, {'Counts': '33'}, {'Counts': '215'}]

# %%
df_citynames = pd.DataFrame(lst_cities)
df_citywise_cases = pd.DataFrame(lst_cases)

# %%
df_citynames
# Out:
#           City
# 0          ICT
# 1       Punjab
# 2        Sindh
# 3           KP
# 4  Balochistan
# 5          AJK
# 6           GB

# %%
df_citywise_cases
# Out:
#   Counts
# 0    107
# 1  2,279
# 2  1,128
# 3    620
# 4    219
# 5     33
# 6    215

# %%
df_col = pd.DataFrame(lst_column_details, columns=['ColumnNames'])
df_col
# Out:
#        ColumnNames
# 0        Recovered
# 1         Critical
# 2           Deaths
# 3   Cases (24 HRS)
# 4  Deaths (24 HRS)
# 5   Tests (24 HRS)
# 6      Total Tests

# %%
df_counts = pd.DataFrame(lst_count_details, columns=['Counts'])
df_counts
# Out:
#    Counts
# 0     727
# 1      45
# 2      66
# 3     284
# 4       4
# 5   2,478
# 6  54,706

# %%
today = dt.now().strftime("%Y-%m-%d")
today
# Out:
# '2020-04-10'

# %%
df_citynames
# Out:
#           City
# 0          ICT
# 1       Punjab
# 2        Sindh
# 3           KP
# 4  Balochistan
# 5          AJK
# 6           GB

# %%
df_final = pd.DataFrame()

# %%
df_final['CityNames'] = df_citynames.City
df_final['Date'] = today
df_final['CityWiseCounts'] = df_citywise_cases.Counts
df_final['Headers'] = df_col['ColumnNames']
df_final['OverallCounts'] = df_counts['Counts']

# %%
df_final
# Out:
#      CityNames        Date CityWiseCounts          Headers OverallCounts
# 0          ICT  2020-04-10            107        Recovered           727
# 1       Punjab  2020-04-10          2,279         Critical            45
# 2        Sindh  2020-04-10          1,128           Deaths            66
# 3           KP  2020-04-10            620   Cases (24 HRS)           284
# 4  Balochistan  2020-04-10            219  Deaths (24 HRS)             4
# 5          AJK  2020-04-10             33   Tests (24 HRS)         2,478
# 6           GB  2020-04-10            215      Total Tests        54,706

# %%
df_file = df_file.append(df_final).reset_index()
df_file
# Out:
# /Users/Muhammad/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#     index    CityNames CityWiseCounts                 Date          Headers  \
# 0       0          ICT            102  2020-04-09 00:00:00        Recovered
# 1       1       Punjab          2,171  2020-04-09 00:00:00         Critical
# 2       2        Sindh          1,128  2020-04-09 00:00:00           Deaths
# 3       3           KP            560  2020-04-09 00:00:00   Cases (24 HRS)
# 4       4  Balochistan            212  2020-04-09 00:00:00  Deaths (24 HRS)
# 5       5          AJK             28  2020-04-09 00:00:00   Tests (24 HRS)
# 6       6           GB            213  2020-04-09 00:00:00      Total Tests
# 7       0          ICT            107           2020-04-10        Recovered
# 8       1       Punjab          2,279           2020-04-10         Critical
# 9       2        Sindh          1,128           2020-04-10           Deaths
# 10      3           KP            620           2020-04-10   Cases (24 HRS)
# 11      4  Balochistan            219           2020-04-10  Deaths (24 HRS)
# 12      5          AJK             33           2020-04-10   Tests (24 HRS)
# 13      6           GB            215           2020-04-10      Total Tests
#
#    OverallCounts
# 0            572
# 1             31
# 2             63
# 3             92
# 4              5
# 5          2,737
# 6         44,896
# 7            727
# 8             45
# 9             66
# 10           284
# 11             4
# 12         2,478
# 13        54,706

# %%
df_file.Date = df_file.Date.astype(str)
# df_final.Date

# %%
df_file.Date = df_file.Date.str.replace(' 00:00:00', '')
# df_final.Date

# %%
df_file.drop(columns=['index'], inplace=True)

# %%
df_file.head(14)
# Out:
#       CityNames CityWiseCounts        Date          Headers OverallCounts
# 0           ICT            102  2020-04-09        Recovered           572
# 1        Punjab          2,171  2020-04-09         Critical            31
# 2         Sindh          1,128  2020-04-09           Deaths            63
# 3            KP            560  2020-04-09   Cases (24 HRS)            92
# 4   Balochistan            212  2020-04-09  Deaths (24 HRS)             5
# 5           AJK             28  2020-04-09   Tests (24 HRS)         2,737
# 6            GB            213  2020-04-09      Total Tests        44,896
# 7           ICT            107  2020-04-10        Recovered           727
# 8        Punjab          2,279  2020-04-10         Critical            45
# 9         Sindh          1,128  2020-04-10           Deaths            66
# 10           KP            620  2020-04-10   Cases (24 HRS)           284
# 11  Balochistan            219  2020-04-10  Deaths (24 HRS)             4
# 12          AJK             33  2020-04-10   Tests (24 HRS)         2,478
# 13           GB            215  2020-04-10      Total Tests        54,706

# %%
ict = df_file.loc[df_file['CityNames'] == 'ICT', ['CityWiseCounts', 'Date']]
punjab = df_file.loc[df_file['CityNames'] == 'Punjab', ['CityWiseCounts', 'Date']]
sindh = df_file.loc[df_file['CityNames'] == 'Sindh', ['CityWiseCounts', 'Date']]
kp = df_file.loc[df_file['CityNames'] == 'KP', ['CityWiseCounts', 'Date']]
balochistan = df_file.loc[df_file['CityNames'] == 'Balochistan', ['CityWiseCounts', 'Date']]
ajk = df_file.loc[df_file['CityNames'] == 'AJK', ['CityWiseCounts', 'Date']]
gb = df_file.loc[df_file['CityNames'] == 'GB', ['CityWiseCounts', 'Date']]

# %%
plt.figure(figsize = (10, 4))

# plt.subplot (1,2,1)

plt.bar(df_file.OverallCounts, df_file.Date)
plt.title('Overall')

# plt.subplot (1,2,2)
# plt.bar(punjab.Date, punjab.CityWiseCounts)
# plt.title('Punjab')

plt.show
# plt.hist(df_file['Headers'], bins=20) #more modality here... more modality means more groups
# plt.show()
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (10, 4))

plt.subplot (1,2,1)

plt.bar(ict.Date, ict.CityWiseCounts)
plt.title('ICT')

plt.subplot (1,2,2)
plt.bar(punjab.Date, punjab.CityWiseCounts)
plt.title('Punjab')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (10, 4))
plt.subplot (1,2,1)
plt.bar(sindh.Date, sindh.CityWiseCounts)
plt.title('Sindh')

plt.subplot(1,2,2)
plt.bar(kp.Date, kp.CityWiseCounts)
plt.title('KP')
plt.show()

# %%
plt.figure(figsize = (10, 4))

plt.subplot (1,2,1)

plt.bar(balochistan.Date, balochistan.CityWiseCounts)
plt.title('Balochistan')

plt.subplot (1,2,2)
plt.bar(ajk.Date, ajk.CityWiseCounts)
plt.title('AJK')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (10, 4))

plt.subplot (1,2,1)

plt.bar(gb.Date, gb.CityWiseCounts)
plt.title('GB')

plt.show()

# %%
df_file.to_excel('Spreadsheets/Corona Stats of Pakistan.xlsx', index=False)
